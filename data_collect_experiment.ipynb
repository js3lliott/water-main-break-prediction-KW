# %%
import pandas as pd
import requests
import datetime

# %%
def extract_data():
    """Extract data from the ArcGIS API."""

    url = 'https://services1.arcgis.com/qAo1OsXi67t7XgmS/arcgis/rest/services/Water_Main_Breaks/FeatureServer/0/query?outFields=*&where=1%3D1&f=geojson'
    response =  requests.get(url)
    data = response.json()

    # converting the GeoJSON file to a dataframe and then applying the pandas series method to extract the features from 'properties' key
    df = pd.DataFrame(data['features'])
    df = df['properties'].apply(pd.Series)
    # saving the dataframe to a csv file with the date it was extracted
    df.to_csv(f'data/raw/break_data_{datetime.datetime.now().strftime("%Y-%m-%d")}.csv', index=False)

    # saving the dataframe to a sqlite database and replacing the older data
    # conn = sqlite3.connect('data/raw/break_data.db')
    # df.to_sql('break_data', conn, if_exists='replace', index=False)
    # conn.close()

    return df


df = extract_data()

# %%
pd.set_option('display.max_columns', None)
df.sample(5)
# Out:
#       OBJECTID  WATBREAKINCIDENTID  INCIDENT_DATE BREAK_TYPE ROAD_CLOSED  \
# 666       8651                2133  1433548800000       MAIN        Open
# 289       8274                 484   887414400000       MAIN        Open
# 789       8774                1101  1171929600000       MAIN        Open
# 1772      9757                1333  1231200000000       MAIN        Open
# 1296      9281                1187  1200528000000       MAIN        Open
#
#      SIDEWALK_CLOSED HOUR_IMPACTED UNITS_IMPACTED  CW_SERVICE_REQUEST  \
# 666             Open    8-12 hours           None                 NaN
# 289             Open    8-12 hours           None                 NaN
# 789             Open    8-12 hours           None                 NaN
# 1772            Open    8-12 hours           None                 NaN
# 1296            Open    8-12 hours           None                 NaN
#
#                 STATUS    STATUS_DATE  WORKORDER  RETURN_TO_NORMAL  \
# 666   REPAIR COMPLETED  1453420800000   134411.0               NaN
# 289   REPAIR COMPLETED  1323963507000        NaN               NaN
# 789   REPAIR COMPLETED  1323963507000   169849.0               NaN
# 1772  REPAIR COMPLETED  1323963508000     2662.0               NaN
# 1296  REPAIR COMPLETED  1323963507000   188152.0               NaN
#
#      BREAK_NATURE BREAK_APPARENT_CAUSE REPAIR_TYPE  NEW_SECTION_LENGTH  \
# 666       UNKNOWN                OTHER        None                 NaN
# 289       UNKNOWN                OTHER        None                 NaN
# 789       UNKNOWN                OTHER        None                 NaN
# 1772      UNKNOWN                OTHER        None                 NaN
# 1296      UNKNOWN                OTHER        None                 NaN
#
#      MAINTENANCE_DESC VALVES_CLOSED VALVES_OPENED HYDRANTS_CALLED_OUT  \
# 666              None          None          None                None
# 289              None          None          None                None
# 789              None          None          None                None
# 1772             None          None          None                None
# 1296             None          None          None                None
#
#      HYDRANTS_CALLED_BACK_IN POSITIVE_PRESSURE_MAINTANED AIR_GAP_MAINTANED  \
# 666                     None                           Y                 Y
# 289                     None                           Y                 Y
# 789                     None                           Y                 Y
# 1772                    None                           Y                 Y
# 1296                    None                           Y                 Y
#
#      DISINFECTED MECHANICAL_REMOVAL FLUSHING_EXCAVATION  \
# 666            Y                  Y                   Y
# 289            Y                  Y                   Y
# 789            Y                  Y                   Y
# 1772           Y                  Y                   Y
# 1296           Y                  Y                   Y
#
#      HIGHER_VELOCITY_FLUSHING ANODE_INSTALLED BREAK_CATEGORIZATION  \
# 666                         Y               Y           CATEGORY 1
# 289                         Y               Y           CATEGORY 1
# 789                         Y               Y           CATEGORY 1
# 1772                        Y               Y           CATEGORY 1
# 1296                        Y               Y           CATEGORY 1
#
#       BACTERIA_TESTING_DATE HEALTH_DEPT_NOTIFICATION MOECC_SAC_NOTIFICATION  \
# 666                     NaN                     None                   None
# 289                     NaN                     None                   None
# 789                     NaN                     None                   None
# 1772                    NaN                     None                   None
# 1296                    NaN                     None                   None
#
#      SAC_REFERENCE_NO LOCAL_MOE_OFFICE BWA_DWA BWA_DWA_DECLARED  \
# 666              None             None       N             None
# 289              None             None       N             None
# 789              None             None       N             None
# 1772             None             None       N             None
# 1296             None             None       N             None
#
#      PROCEEDURES_FOLLOWED RECORD_CHANGE_REQD  ROADSEGMENTID CIVIC_NUMBER  \
# 666                     Y                  N          20691           59
# 289                     Y                  N          11581           64
# 789                     Y                  N          21762           42
# 1772                    Y                  N          23231           48
# 1296                    Y                  N           5722           35
#
#                  STREET  ASSETID  ASSET_DEPTH  FROST_DEPTH  ASSET_SIZE  \
# 666   SILVERSPRING CRES    35030          NaN          NaN       150.0
# 289      CHARLOTTE CRES     6940          NaN          NaN       150.0
# 789            BIEHN DR    86632          NaN          NaN       200.0
# 1772      TECUMSEH CRES    88910          NaN          NaN       150.0
# 1296      HIGHLAND RD E    19030          NaN          NaN       150.0
#
#      ASSET_YEAR_INSTALLED ASSET_MATERIAL ASSET_EXISTS  \
# 666                  1967             CI            Y
# 289                  1960             CI            Y
# 789                  1976             DI            Y
# 1772                 1965             CI            Y
# 1296                 1933             CI            Y
#
#                                   GLOBALID
# 666   5b35c44b-04ce-446a-9589-4aa035e5d335
# 289   2b117ff8-e0d7-497b-8d51-beb3bd635004
# 789   942bea18-dac5-4c9d-b7ee-6f41dd3068eb
# 1772  921dee86-6e97-42a5-b795-0b6874defcf1
# 1296  7b4b21aa-1a4f-4a9e-996c-cee2392169f5

# %%
df.shape
# Out:
# (2000, 50)
