# %%
import pandas as pd
import requests

# %%
url = 'https://services1.arcgis.com/qAo1OsXi67t7XgmS/arcgis/rest/services/Water_Mains/FeatureServer/0/query?outFields=*&where=1%3D1&f=geojson'
response =  requests.get(url)
data = response.json()

# converting the GeoJSON file to a dataframe and then applying the pandas series method to extract the features from 'properties' key
df1 = pd.DataFrame(data['features'])
df1 = df1['properties'].apply(pd.Series)
# saving the dataframe to a csv file with the date it was extracted
df1.to_csv('data/raw/water_main_V1.csv', index=False)

# %%
url = 'https://services1.arcgis.com/qAo1OsXi67t7XgmS/arcgis/rest/services/Water_Main_Breaks/FeatureServer/0/query?outFields=*&where=1%3D1&f=geojson'
response =  requests.get(url)
data = response.json()

# converting the GeoJSON file to a dataframe and then applying the pandas series method to extract the features from 'properties' key
df2 = pd.DataFrame(data['features'])
df2 = df2['properties'].apply(pd.Series)
# saving the dataframe to a csv file with the date it was extracted
df2.to_csv('data/raw/water_main_break_V1.csv', index=False)

# %%
merged_df = pd.merge(df1, df2, on='ROADSEGMENTID', how='left')

# %%
merged_df.sample(7)
# Out:
#       OBJECTID_x  WATMAINID STATUS_x PRESSURE_ZONE  ROADSEGMENTID  \
# 2389       79970      84570   ACTIVE         KIT 4          10958
# 2223       79809      84424   ACTIVE         KIT 4          12101
# 1310       78977      34710   ACTIVE         KIT 4          10088
# 2444       80008      84612   ACTIVE         KIT 5         600121
# 1451       79105      59020   ACTIVE         KIT 4          22429
# 1813       79417      84142   ACTIVE       KIT 2EA         601515
# 2425       79994      65900   ACTIVE         KIT 5          40324
#
#               MAP_LABEL CATEGORY  PIPE_SIZE MATERIAL LINED  ...  CIVIC_NUMBER  \
# 2389     6.6m 150mm  CI  TREATED        150       CI    NO  ...            16
# 2223    9.9m 300mm  PVC  TREATED        300      PVC    NO  ...           NaN
# 1310   244.3m 300mm  DI  TREATED        300       DI    NO  ...           NaN
# 2444    3.9m 200mm  PVC  TREATED        200      PVC    NO  ...           NaN
# 1451  124.1m 150mm  PVC  TREATED        150      PVC    NO  ...           839
# 1813    7.6m 150mm  PVC  TREATED        150      PVC    NO  ...           NaN
# 2425   39.4m 300mm  PVC  TREATED        300      PVC    NO  ...           NaN
#
#             STREET  ASSETID ASSET_DEPTH FROST_DEPTH ASSET_SIZE  \
# 2389  WOODHAVEN RD  43970.0         NaN         NaN      150.0
# 2223           NaN      NaN         NaN         NaN        NaN
# 1310           NaN      NaN         NaN         NaN        NaN
# 2444           NaN      NaN         NaN         NaN        NaN
# 1451  FAIRWAY CRES  83830.0         NaN         NaN      150.0
# 1813           NaN      NaN         NaN         NaN        NaN
# 2425           NaN      NaN         NaN         NaN        NaN
#
#      ASSET_YEAR_INSTALLED ASSET_MATERIAL  ASSET_EXISTS  \
# 2389                 1957             CI             Y
# 2223                  NaN            NaN           NaN
# 1310                  NaN            NaN           NaN
# 2444                  NaN            NaN           NaN
# 1451                 1995            PVC             Y
# 1813                  NaN            NaN           NaN
# 2425                  NaN            NaN           NaN
#
#                                   GLOBALID
# 2389  422b5263-7e0d-46de-8451-c6ef3daf7c70
# 2223                                   NaN
# 1310                                   NaN
# 2444                                   NaN
# 1451  65cd8804-b775-4009-8efb-a6b86868d0ba
# 1813                                   NaN
# 2425                                   NaN
#
# [7 rows x 77 columns]

# %%
merged_df.shape
# Out:
# (2473, 77)

# %%
df1.shape
# Out:
# (2000, 28)

# %%
df2.shape
# Out:
# (2000, 50)

# %% [markdown]
# The API's seem to only be loading in 2,000 rows for each set of data. Instead of calling the API maybe download the data for each set and then merge them.
